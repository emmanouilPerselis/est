# %%
#importing package(s)
import numpy as np

# %% [markdown]
# 1) Exercices on creating numpy arrays.
#
# Make a numpy array with values from -1.3 to 2.5. The value 2.5 should be present in the
# array (inclusive). The array should be of size 64 with equal steps between the values

# %%
np.arange(-1.3,2.6,0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-381ae52d32e3> in <module>()
# ----> 1 a = np.linspace((1.3,2.5),64)
#       2 print("size is:" ,a.size)
#       3 print("last value is:", a[-1])
#
# NameError: name 'np' is not defined

# %% [markdown]
# Make a function repeat that takes n as argument. This funcion should return a numpy array of size 3nwith the values 1,2,3 repeating. for example for n=2 : array = [1,2,3,1,2,3].

# %%
import numpy as np


def function(n):
    arr = np.array([1,2,3])
    np.tile(arr,n)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-674425d3d869> in <module>()
# ----> 1 import numpy as np
#       2 arr = np.array([1,2,3])
#       3 np.tile(arr,3)
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# Make an array of the first 10 odd numbers

# %%
np.arange(1,20,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1137dfe62662> in <module>()
# ----> 1 display(np.arange(1,20,2))
#
# NameError: name 'np' is not defined

# %% [markdown]
# Make a numpy array of shape = (8,8) (an 8x8 by array) with a checkerboard pattern of 0's and 1's.
#
# To Do this first make the array : [ 0, 1, 0, 1, 0, 1, 0, 1] and use this to make the completeboard. Only the first row can be made with the above list and np.array().
#
# Use display() or print() to show the resulting numpy array.

# %%
a1 = np.array([0 if i%2 == 0 else 1 for i in range(8)])
a2 = np.array([1 if i%2 == 0 else 0 for i in range(8)])
array = np.array([0 if i%2 == 0 else 1 for i in range(8)])
array = np.append([array],[a2], axis=0)
array = np.append(array,array, axis=0)
array = np.append(array,array, axis=0)
print(array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-efd2a30f3ca3> in <module>()
#       1 #two ways to make the first row.
# ----> 2 a= np.array([0, 1, 0, 1, 0, 1, 0, 1])
#       3 a = np.array([0 if i%2 == 0 else 1 for i in range(8)])
#       4
#       5 #two ways to make second row from first row.
#
# NameError: name 'np' is not defined
